# %%
# %load_ext autoreload
# %autoreload 2

# %%
from opera_tropo import product_info
from opera_tropo.config import pge_runconfig, runconfig
from opera_tropo.utils import get_hres_datetime

# %% [markdown]
# # Product info
# metadata of the output product

# %%
tropo = product_info.TROPO_PRODUCTS

# %%
for item, key in tropo.__dict__.items():
    print(item,'\n',50*'#')
    for i, ik in key.__dict__.items():
        if item == 'coords':
            print(i)
            for ix, ik in ik.__dict__.items():
                print(' ', ix,':', ik)
        else:
            print(i,':', ik)

    print('\n')
# Out:
# wet_delay
#  ##################################################
# name : wet_delay
# long_name : Zenith Wet Delay
# description : Zenith-integrated Wet Delay.
# fillvalue : 9.96921e+36
# missing_value : 9.96921e+36
# dtype : <class 'numpy.float32'>
# keep_bits : 10
# attrs : {'units': 'meters', 'grid_mapping': 'spatial_ref'}
#
#
# hydrostatic_delay
#  ##################################################
# name : hydrostatic_delay
# long_name : Zenith Hydrostatic Delay
# description : Zenith-integrated Wet Delay.
# fillvalue : 9.96921e+36
# missing_value : 9.96921e+36
# dtype : <class 'numpy.float32'>
# keep_bits : 12
# attrs : {'units': 'meters', 'grid_mapping': 'spatial_ref'}
#
#
# coords
#  ##################################################
# latitude
#   axis : Y
#   units : degrees_north
#   standard_name : latitude
#   long_name : Latitude
#   description : Angular distance of a point north or south of the equator.
#   encoding : {}
# longitude
#   axis : X
#   units : degrees_east
#   standard_name : longitude
#   long_name : Longitude
#   description : Angular distance of a point east or west of the Prime Meridian.
#   encoding : {}
# height
#   axis : Z
#   units : meters
#   standard_name : height
#   long_name : Ellipsoidal Height
#   description : Height above ellipsoid WGS84
#   encoding : {}
# time
#   axis : T
#   units : None
#   standard_name : time
#   long_name : UTC time
#   description : Numerical Weather Model base time
#   encoding : {'units': 'hours since 1900-01-01', 'calendar': 'gregorian'}

# %% [markdown]
# # Configuration

# %%
tropo_workflow = runconfig.TropoWorkflow
tropo_workflow = tropo_workflow.from_yaml('../src/opera_tropo/config/default/runconfig.yaml')

# %%
# Print config defaults
tropo_workflow.print_yaml_schema()
# Out:
# input_options:
#   # Path to the input HRES model hres_model.nc.
#   #   Type: string | string.
#   input_file_path: ''
#   # Format of dates contained in s3 HRES folder.
#   #   Type: string.
#   date_fmt: '%Y%m%d'
# output_options:
#   # Output Date Format for OPERA TROPO.
#   #   Type: string.
#   date_fmt: '%Y%m%dT%H%M%S'
#   # Time the config file was created.
#   #   Type: string.
#   creation_time: '2025-06-26T23:31:02.057439Z'
#   # Clip heights above specified maximum height.
#   #   Type: integer.
#   max_height: 81000
#   # Output height level to hydrostatic and wet delay, default: HRES native 145 height levels.
#   #   Type: array | null.
#   output_heights:
#     - -500.0
#     - -300.0
#     - -200.0
#     - -100.0
#     - -50.0
#     - -20.0
#     - -10.0
#     - 0.0
#     - 10.0
#     - 30.96
#     - 53.92
#     - 79.04
#     - 106.54
#     - 136.62
#     - 169.51
#     - 205.44
#     - 244.69
#     - 287.52
#     - 334.24
#     - 385.16
#     - 440.61
#     - 500.95
#     - 566.54
#     - 637.76
#     - 715.02
#     - 798.72
#     - 889.29
#     - 987.15
#     - 1092.73
#     - 1206.44
#     - 1328.7
#     - 1459.91
#     - 1600.44
#     - 1750.63
#     - 1910.76
#     - 2081.09
#     - 2261.8
#     - 2452.99
#     - 2654.69
#     - 2866.83
#     - 3089.25
#     - 3321.67
#     - 3563.69
#     - 3814.82
#     - 4074.41
#     - 4341.73
#     - 4615.92
#     - 4896.02
#     - 5180.98
#     - 5469.3
#     - 5759.3
#     - 6049.89
#     - 6340.68
#     - 6631.66
#     - 6922.8
#     - 7214.09
#     - 7505.51
#     - 7797.04
#     - 8088.67
#     - 8380.36
#     - 8672.11
#     - 8963.9
#     - 9255.7
#     - 9547.49
#     - 9839.26
#     - 10130.98
#     - 10422.64
#     - 10714.22
#     - 11005.69
#     - 11297.93
#     - 11592.86
#     - 11890.24
#     - 12190.1
#     - 12492.44
#     - 12797.3
#     - 13104.7
#     - 13414.65
#     - 13727.18
#     - 14042.3
#     - 14360.05
#     - 14680.44
#     - 15003.5
#     - 15329.24
#     - 15657.7
#     - 15988.88
#     - 16322.83
#     - 16659.55
#     - 16999.08
#     - 17341.62
#     - 17687.77
#     - 18038.35
#     - 18394.25
#     - 18756.34
#     - 19125.61
#     - 19503.09
#     - 19889.88
#     - 20286.66
#     - 20694.9
#     - 21114.77
#     - 21546.62
#     - 21990.82
#     - 22447.75
#     - 22917.85
#     - 23401.71
#     - 23900.02
#     - 24413.5
#     - 24942.93
#     - 25489.15
#     - 26053.04
#     - 26635.56
#     - 27237.73
#     - 27860.64
#     - 28505.47
#     - 29173.5
#     - 29866.09
#     - 30584.71
#     - 31330.96
#     - 32106.57
#     - 32915.27
#     - 33763.05
#     - 34652.52
#     - 35586.89
#     - 36569.72
#     - 37604.95
#     - 38696.94
#     - 39850.56
#     - 41071.2
#     - 42364.93
#     - 43738.55
#     - 45199.69
#     - 46756.98
#     - 48413.94
#     - 50159.36
#     - 51996.21
#     - 53905.62
#     - 55882.68
#     - 57930.78
#     - 60053.46
#     - 62254.39
#     - 64537.43
#     - 66906.53
#     - 69365.77
#     - 71918.79
#     - 74584.91
#     - 80301.65
#   # Ouput chunks (time, height, lat, lon).
#   #   Type: array.
#   chunk_size:
#     - 1
#     - 64
#     - 64
#     - 64
#   # Product output compression options for netcdf.
#   #   Type: object | null.
#   compression_kwargs:
#     zlib: true
#     complevel: 5
#     shuffle: true
#   # OPERA TROPO product version.
#   #   Type: string.
#   product_version: '0.2'
# # Name of directory to use for processing.
# #   Type: string.
# work_directory: /u/aurora-r0/govorcin/01_OPERA/TROPO/final/tropo/notebooks
# # Name of directory to use for writing output files.
# #   Type: string.
# output_directory: .
# # Don't resolve filepaths that are given as relative to be absolute.
# #   Type: boolean.
# keep_paths_relative: false
# worker_settings:
#   # Number of workers to use in dask.Client.
#   #   Type: integer.
#   n_workers: 4
#   # Number of threads to use per worker in dask.Client.
#   #   Type: integer.
#   threads_per_worker: 2
#   # Workers are given a target memory limit in dask.Client.
#   #   Type: integer | string.
#   max_memory: 6GB
#   # Dask local spill directory within work directory.
#   #   Type: string | string.
#   dask_temp_dir: tmp
#   # Size (rows, columns) of blocks of data to load at a time.
#   #   Type: array.
#   block_shape:
#     - 128
#     - 128
# # Path to output log file (in addition to logging to `stderr`). Default logs to `tropo.log`
# #   within `work_directory`.
# #   Type: string | null.
# log_file:

# %%
# Print configuration parameters
tropo_workflow.model_dump()
# Out:
# {'input_options': {'input_file_path': 'input_data/D01010000010100001.zz.nc',
#   'date_fmt': '%Y%m%d'},
#  'output_options': {'date_fmt': '%Y%m%dT%H%M%S',
#   'creation_time': datetime.datetime(2025, 6, 26, 23, 31, 0, 478202, tzinfo=datetime.timezone.utc),
#   'max_height': 81000,
#   'output_heights': [],
#   'chunk_size': (1, 64, 64, 64),
#   'compression_kwargs': {'zlib': True, 'complevel': 5, 'shuffle': True},
#   'product_version': '0.2'},
#  'work_directory': PosixPath('/u/aurora-r0/govorcin/01_OPERA/TROPO/final/tropo/notebooks'),
#  'output_directory': PosixPath('.'),
#  'keep_paths_relative': False,
#  'worker_settings': {'n_workers': 4,
#   'threads_per_worker': 2,
#   'max_memory': '8GB',
#   'dask_temp_dir': 'tmp',
#   'block_shape': (128, 128)},
#  'log_file': PosixPath('log_sas.log')}

# %%
# Get model datetime and hour
tropo_workflow.input_options.input_file_path = 'download_test/ECMWF_TROP_202409100600_202409100600_1.nc'
hres_dt = get_hres_datetime(tropo_workflow.input_options.input_file_path)
hres_dt
# Out:
# ('20240910', 6)

# %%
# Get output filename
#OPERA_L{level}_{product_name}_{spatial_coverage}_{hres_model_datetime}_{process_start_datetime}_{WEATHER_MODEL}_{HRES_spatial_resolution}_{product_version}.nc
tropo_workflow.output_options.get_output_filename(*hres_dt)
# Out:
# 'OPERA_L4_TROPO-ZENITH_20240910T060000Z_20250626T233100Z_HRES_v0.2.nc'

# %%
#PGE runconfig contains few extra fields
pge_workflow = pge_runconfig.RunConfig()
pge_workflow = pge_workflow.from_yaml('../src/opera_tropo/config/default/pge_runconfig.yaml')
pge_workflow.model_dump()
# Out:
# {'input_file': {'input_file_path': 'input_data/D01010000010100001.zz.nc',
#   'date_fmt': '%Y%m%d'},
#  'output_options': {'date_fmt': '%Y%m%dT%H%M%S',
#   'creation_time': datetime.datetime(2025, 6, 26, 23, 32, 11, 844129, tzinfo=datetime.timezone.utc),
#   'max_height': 81000,
#   'output_heights': [-500,
#    -300,
#    -200,
#    -100,
#    -50,
#    -20,
#    -10,
#    0,
#    10,
#    30.96,
#    53.92,
#    79.04,
#    106.54,
#    136.62,
#    169.51,
#    205.44,
#    244.69,
#    287.52,
#    334.24,
#    385.16,
#    440.61,
#    500.95,
#    566.54,
#    637.76,
#    715.02,
#    798.72,
#    889.29,
#    987.15,
#    1092.73,
#    1206.44,
#    1328.7,
#    1459.91,
#    1600.44,
#    1750.63,
#    1910.76,
#    2081.09,
#    2261.8,
#    2452.99,
#    2654.69,
#    2866.83,
#    3089.25,
#    3321.67,
#    3563.69,
#    3814.82,
#    4074.41,
#    4341.73,
#    4615.92,
#    4896.02,
#    5180.98,
#    5469.3,
#    5759.3,
#    6049.89,
#    6340.68,
#    6631.66,
#    6922.8,
#    7214.09,
#    7505.51,
#    7797.04,
#    8088.67,
#    8380.36,
#    8672.11,
#    8963.9,
#    9255.7,
#    9547.49,
#    9839.26,
#    10130.98,
#    10422.64,
#    10714.22,
#    11005.69,
#    11297.93,
#    11592.86,
#    11890.24,
#    12190.1,
#    12492.44,
#    12797.3,
#    13104.7,
#    13414.65,
#    13727.18,
#    14042.3,
#    14360.05,
#    14680.44,
#    15003.5,
#    15329.24,
#    15657.7,
#    15988.88,
#    16322.83,
#    16659.55,
#    16999.08,
#    17341.62,
#    17687.77,
#    18038.35,
#    18394.25,
#    18756.34,
#    19125.61,
#    19503.09,
#    19889.88,
#    20286.66,
#    20694.9,
#    21114.77,
#    21546.62,
#    21990.82,
#    22447.75,
#    22917.85,
#    23401.71,
#    23900.02,
#    24413.5,
#    24942.93,
#    25489.15,
#    26053.04,
#    26635.56,
#    27237.73,
#    27860.64,
#    28505.47,
#    29173.5,
#    29866.09,
#    30584.71,
#    31330.96,
#    32106.57,
#    32915.27,
#    33763.05,
#    34652.52,
#    35586.89,
#    36569.72,
#    37604.95,
#    38696.94,
#    39850.56,
#    41071.2,
#    42364.93,
#    43738.55,
#    45199.69,
#    46756.98,
#    48413.94,
#    50159.36,
#    51996.21,
#    53905.62,
#    55882.68,
#    57930.78,
#    60053.46,
#    62254.39,
#    64537.43,
#    66906.53,
#    69365.77,
#    71918.79,
#    74584.91,
#    80301.65],
#   'chunk_size': (1, 64, 64, 64),
#   'compression_kwargs': {'zlib': True, 'complevel': 5, 'shuffle': True},
#   'product_version': '0.2'},
#  'primary_executable': {'product_type': 'OPERA_TROPO'},
#  'product_path_group': {'product_path': PosixPath('output/historical'),
#   'scratch_path': PosixPath('scratch'),
#   'output_path': PosixPath('output/historical'),
#   'product_version': '0.2'},
#  'worker_settings': {'n_workers': 4,
#   'threads_per_worker': 2,
#   'max_memory': '8GB',
#   'dask_temp_dir': 'tmp',
#   'block_shape': (128, 128)},
#  'log_file': PosixPath('golden_output/log_sas.log')}

# %%
# Get tropoworkflow config from pge_config
pge_workflow.to_workflow()
# Out:
# TropoWorkflow(input_options=InputOptions(input_file_path='input_data/D01010000010100001.zz.nc', date_fmt='%Y%m%d'), output_options=OutputOptions(date_fmt='%Y%m%dT%H%M%S', creation_time=datetime.datetime(2025, 6, 26, 23, 32, 11, 844129, tzinfo=datetime.timezone.utc), max_height=81000, output_heights=[-500.0, -300.0, -200.0, -100.0, -50.0, -20.0, -10.0, 0.0, 10.0, 30.96, 53.92, 79.04, 106.54, 136.62, 169.51, 205.44, 244.69, 287.52, 334.24, 385.16, 440.61, 500.95, 566.54, 637.76, 715.02, 798.72, 889.29, 987.15, 1092.73, 1206.44, 1328.7, 1459.91, 1600.44, 1750.63, 1910.76, 2081.09, 2261.8, 2452.99, 2654.69, 2866.83, 3089.25, 3321.67, 3563.69, 3814.82, 4074.41, 4341.73, 4615.92, 4896.02, 5180.98, 5469.3, 5759.3, 6049.89, 6340.68, 6631.66, 6922.8, 7214.09, 7505.51, 7797.04, 8088.67, 8380.36, 8672.11, 8963.9, 9255.7, 9547.49, 9839.26, 10130.98, 10422.64, 10714.22, 11005.69, 11297.93, 11592.86, 11890.24, 12190.1, 12492.44, 12797.3, 13104.7, 13414.65, 13727.18, 14042.3, 14360.05, 14680.44, 15003.5, 15329.24, 15657.7, 15988.88, 16322.83, 16659.55, 16999.08, 17341.62, 17687.77, 18038.35, 18394.25, 18756.34, 19125.61, 19503.09, 19889.88, 20286.66, 20694.9, 21114.77, 21546.62, 21990.82, 22447.75, 22917.85, 23401.71, 23900.02, 24413.5, 24942.93, 25489.15, 26053.04, 26635.56, 27237.73, 27860.64, 28505.47, 29173.5, 29866.09, 30584.71, 31330.96, 32106.57, 32915.27, 33763.05, 34652.52, 35586.89, 36569.72, 37604.95, 38696.94, 39850.56, 41071.2, 42364.93, 43738.55, 45199.69, 46756.98, 48413.94, 50159.36, 51996.21, 53905.62, 55882.68, 57930.78, 60053.46, 62254.39, 64537.43, 66906.53, 69365.77, 71918.79, 74584.91, 80301.65], chunk_size=(1, 64, 64, 64), compression_kwargs={'zlib': True, 'complevel': 5, 'shuffle': True}, product_version='0.2'), work_directory=PosixPath('/u/aurora-r0/govorcin/01_OPERA/TROPO/final/tropo/notebooks/scratch'), output_directory=PosixPath('output/historical'), keep_paths_relative=False, worker_settings=WorkerSettings(n_workers=4, threads_per_worker=2, max_memory='8GB', dask_temp_dir='scratch/tmp', block_shape=(128, 128)), log_file=PosixPath('golden_output/log_sas.log'))
